# %% [markdown]
# In this notebook I should train the HCLA ref data using scVI and scANVI to generate a model to use for label tranfering

# %% [markdown]
# This notebook was erased by mistake and I have it pending to do it again.
